015842894, 0.014195234, -0.011176442, 0.027837407, -0.016349867, -0.015140046, 0.0146330735, 0.050927706, -0.0075008906, 0.00897572, 0.020428693, -0.0075930674, 0.008768322, -0.037331622, -0.0051791864, -0.006803803, 0.02555603, 0.0015785284, 0.017916873, -0.0054096286, 0.011090026, 0.029680943, 0.040765207, 0.025256455, 0.03885254, -0.026915638, 0.018020572, 0.004559873, 0.0061988924, 0.008105801, 0.02014064, 0.011775591, 0.006602166, -0.04820849, 0.020463258, -0.0074951295, 0.010150975, -0.0060433443, -0.025970826, -0.03320671, -0.04417575, -0.013400208, 0.018988429, 0.031455345, -0.0045569926, -0.022053309, -0.024219465, -0.025002968, -0.024703393, -0.040626943, 0.024818614, -0.0025219007, 0.058901, 0.0075008906, -0.029289192, -0.06277243, -0.0020178086, -0.0031052073, -0.005778336, -0.031939276, 0.0348198, 0.015289834, 0.009396276, -0.014967214, 0.0024282837, -0.017813174, 0.024265554, 0.02857482, 0.0064927065, -0.041318268, 0.039543863, 0.045212742, -0.008094279, -0.011971467, -0.0071955547, 0.031893186, -0. ...

# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'd:\finetuning\fullfinetuning\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
result = response.json()

# %%
len(result['data'][0]['embedding'])
# Out:
# 1536

# %%
a = result['data'][0]['embedding']

# %%
import requests

url = "https://api.euron.one/api/v1/euri/embeddings"
token = "euri-dba285d182559f8ab3a83fc56de1ca41f830207404b14aa62343d706d5c61b31"

payload = {
    "input": "sudhanshu use to work for euron",
    "model": "text-embedding-3-small"
}

response = requests.post(url, json=payload, headers={"Authorization": f"Bearer {token}"})
b = response.json()['data'][0]['embedding']

# %%
import requests

url = "https://api.euron.one/api/v1/euri/embeddings"
token = "euri-dba285d182559f8ab3a83fc56de1ca41f830207404b14aa62343d706d5c61b31"

payload = {
    "input": "rakesh a gen ai batch student",
    "model": "text-embedding-3-small"
}

response = requests.post(url, json=payload, headers={"Authorization": f"Bearer {token}"})
c = response.json()['data'][0]['embedding']

# %%
a,b,c

# %%
import requests

url = "https://api.euron.one/api/v1/euri/embeddings"
token = "euri-dba285d182559f8ab3a83fc56de1ca41f830207404b14aa62343d706d5c61b31"

payload = {
    "input": "what sudhanshu does",
    "model": "text-embedding-3-small"
}

response = requests.post(url, json=payload, headers={"Authorization": f"Bearer {token}"})
inp = response.json()['data'][0]['embedding']

# %%
import numpy as np

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.5-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.5-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 13.1/13.1 MB 82.2 MB/s  0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.3.5
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'd:\finetuning\fullfinetuning\.conda\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
type(a)
# Out:
# list

# %%
a = np.array(a)
b= np.array(b)
c = np.array(c)
inp = np.array(inp)

# %%
a,b,c,inp
# Out:
# (array([-0.00645238, -0.02682346, -0.02852873, ..., -0.00969585,
#          0.01474829, -0.00714371], shape=(1536,)),
#  array([-0.0461162 , -0.00981342,  0.05917026, ...,  0.00189482,
#          0.00919579, -0.01663782], shape=(1536,)),
#  array([-0.00416988, -0.03700995,  0.05361585, ..., -0.03120966,
#          0.05270311, -0.01773945], shape=(1536,)),
#  array([-0.03277422,  0.00336288,  0.05129212, ..., -0.00561822,
#         -0.00875308,  0.00986446], shape=(1536,)))

# %%
dist_inp_a = np.linalg.norm(inp-a)
dist_inp_b = np.linalg.norm(inp-b)
dist_inp_c = np.linalg.norm(inp-c)

# %%
dist_inp_a , dist_inp_b, dist_inp_c
# Out:
# (np.float64(0.7504763757808104),
#  np.float64(0.8504144454236802),
#  np.float64(1.1830916304539874))
